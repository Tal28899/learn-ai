# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
print( "Data" ,"Science" ,"Mentorship" ,"Program",
"By", "CampusX",sep='-',end=' ')
print ('Talha')
# Out:
# Data-Science-Mentorship-Program-By-CampusX Talha

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
#Taking value from user and storing it in variable
Cel=float(input("Enter Temperature in Celcius"))
# formula to convert celsius into farenhite
Fer = (Cel * 1.8) + 32
# printing the results
print(f"Temperature :{Fer} farenhite")
# Out:
# Enter Temperature in Celcius38
# Temperature :100.4 farenhite

# %%
# taking input from user
num1 = int(input("enter first number"))
num2 = int(input("enter second number"))
# swaping numbers
temp = num1
num1 = num2
num2 = temp
num2_swaped = num1
# printing the result
print ( f"swaped num1 : {num1}")
print ( f"swaped num2 : {num2}")
# Out:
# enter first number5
# enter second number4
# swaped num1 : 4
# swaped num2 : 5

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
# importing math libarary to perform calculations
import math
#getting coordinates from user
x1,y1 =map(int,input('enter first vector coordinates (x,y) : ').split(","))
x2,y2 =map(int,input('enter second vector coordinates (x,y) : ').split(","))
# Formula to find eucladian distance
ed = math.sqrt((x2-x1)**2 + (y2-y1)**2)
# printing the results
print(f"eucladian distance is : {ed}")
# Out:
# enter first vector coordinates (x,y) : 2,3
# enter second vector coordinates (x,y) : 4,8
# eucladian distance is : 5.385164807134504

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# taking input
prin_amount = int(input("Enter the principal amount : "))
interest_ra = float(input("Enter the rate of interest : "))
time = float(input("Enter time duration in years: "))
# formula to calculate simple interest
sim_interest = prin_amount * interest_ra * time / 100
print(f"Total simple interest is : {sim_interest} ")
# Out:
# Enter the principal amount : 6000
# Enter the rate of interest : 2.5
# Enter time duration in years: 5
# Total simple interest is : 750.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
# taking value from the user
legs = int(input("Enter no of legs : "))
heads = int(input("Enter no of heads : "))

# formula for counting no of chicken and dogs
dogs = (legs - 2*heads)//2
chickens = heads - dogs
# Handling errors
if dogs < 0 or chickens < 0 or legs%2 != 0:
  print('Invalid values for legs and heads')
else:
  #printing the results
  print(f"total no of dogs = {dogs}")
  print(f"total no of chicken = {chickens}")
# Out:
# Enter no of legs : 34
# Enter no of heads : 12
# total no of dogs = 5
# total no of chicken = 7

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
#taking nth value from user
Value_n = int(input("Enter a natural number : "))
# sum of all given natural numbers
total_sum = 0 # initial value
# running loop
for x in range(1,Value_n + 1):
   total_sum += x
# calculating mean
mean = total_sum / Value_n

#calculating sum of saqures(ss)
ss = 0
for x in range (1,Value_n + 1):
  saq_diff = (x - mean)**2
  ss += saq_diff
#printing the results
print(f"Sum of saqures error = {ss}")
# Out:
# Enter a natural number : 4
# Sum of saqures error = 5.0

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
#taking input from the user
num1 =int(input("enter first number of the series: "))
num2 =int(input("enter second number of the series: "))
val_find_num =int(input("enter  number of the series you want to know: "))

#figuring out the sequence of the series
series_seq = num2 - num1

# finding the value of the number
value_num = num1 + (series_seq * (val_find_num - 1))

#printing the results
print(f"The value of {val_find_num}th number of the series is : {value_num}")
# Out:
# enter first number of the series: 7
# enter second number of the series: 14
# enter  number of the series you want to know: 5
# The value of 5 number of the series is : 35

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
import math

# Taking numerator and denominator for the first fraction from user
nume1 = int(input("Enter numerator for fraction 1: "))
deno1 = int(input("Enter denominator for fraction 1: "))

# Taking numerator and denominator for the second fraction from user
nume2 = int(input("Enter numerator for fraction 2: "))
deno2 = int(input("Enter denominator for fraction 2: "))

# Calculate a common denominator
common_deno = deno1 * deno2

# Adjust numerators to the common denominator
adjusted_nume1 = nume1 * deno2
adjusted_nume2 = nume2 * deno1

# Sum the adjusted numerators
sum_nume = adjusted_nume1 + adjusted_nume2

# Find the greatest common divisor (GCD) to simplify the fraction
gcd_val = math.gcd(sum_nume, common_deno)

# Simplify the fraction
simplified_nume = sum_nume // gcd_val
simplified_deno = common_deno // gcd_val

# Printing the result
print(f"The sum of the fractions is: {simplified_nume}/{simplified_deno}")
# Out:
# Enter numerator for fraction 1: 2
# Enter denominator for fraction 1: 4
# Enter numerator for fraction 2: 5
# Enter denominator for fraction 2: 3
# The sum of the fractions is: 13/6

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# taking tank measurement from the user

import math
tank_height  = int(input("Enter the height of the tank : "))
tank_length  = int(input("Enter the lenght of the tank : "))
tank_width  = int(input("Enter the width of the tank : "))

# taking glass measurement from the user
glass_height  = int(input("Enter the height of the glass : "))
glass_radius  = int(input("Enter the radius of the glass : "))

# calculating volume of the milk tank
milk_tank_vol = (tank_height * tank_width * tank_length)

# calculating volume of the glass
glass_vol = (glass_height * (glass_radius)**2 * math.pi)

# calculating total milk glasses obtained
total_milk_glass = milk_tank_vol// glass_vol
print(total_milk_glass)
# Out:
# Enter the height of the tank : 20
# Enter the lenght of the tank : 20
# Enter the width of the tank : 20
# Enter the height of the glass : 3
# Enter the radius of the glass : 1
# 848.0
